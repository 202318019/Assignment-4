# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      |▍
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      |████████████████████████████████| 317.0 MB 7.0 kB/s
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 38.7 MB/s
# Building wheels for collected packages: pyspark
# done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488511 sha256=dc496af5c9317ef2765bd022bf7eb8b440bb311b49dfe56aac50efbaff00bbd1
#   Stored in directory: /root/.cache/pip/wheels/92/09/11/aa01d01a7f005fda8a66ad71d2be7f8aa341bddafb27eee3c7
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.7 pyspark-3.5.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-e044d9f1-1428-443c-9fb7-278be5aa6745/bin/python -m pip install --upgrade pip' command.

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf

# %%
config = SparkConf()
config.setMaster("local").setAppName("MapReduce")
print(f' Master URL: {config.get("spark.master")}')
print(f' App Name: {config.get("spark.app.name")}')
# Out:
#  Master URL: local
#  App Name: MapReduce

# %%
spk_cntxt = SparkContext.getOrCreate()
spk_cntxt
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3321560113171825#setting/sparkui/0228-183825-orvded3p/driver-8337963192587264397">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
spark = SparkSession.builder.appName("MapReduce").master("local").getOrCreate()

# %%
 spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3321560113171825#setting/sparkui/0228-183825-orvded3p/driver-8337963192587264397">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
path = 'dbfs:/FileStore/shared_uploads/202318019@daiict.ac.in/ice_cream.txt'
rdd = spark.sparkContext.textFile(path) # RDD created

# %%
lines = spk_cntxt.textFile(path)

# %%
rdd.collect()
# Out:
# Out[26]: ['Ever since my first lick of ice cream, it has been an endless love story. Trading my toy out for ice cream at Chick-fil-a was the easiest decision I ever had to make. I spent every spring, summer, fall, and winter craving ice cream when I was happy, sad and anywhere in between. After giving up dairy, I thought my long and faithful love story with ice cream had come crashing to an end, but I soon realized how many other options I have.',
#  '',
#  'The first destination on my road to discovering dairy-free ice cream options landed with the classic sorbet. This dairy- and nut-free option is also free of most common allergens while maintaining a delicious taste. Sorbet has sat back seat to ice cream for years, but at almost nearly any ice cream store you can find sorbet. It’s very sweet, so it easily curbs any sweet tooth. While it might not be quite as creamy as regular ice cream, it’s a great way to satiate your sugar cravings and quench your thirst at the same time.',
#  '',
#  'One of the things that made me fall in love with ice cream is its creamy texture that melts in my mouth. Although sorbet may not feature this, there are numerous vegan, soy, nut and coconut-based ice creams that provide the same creamy texture and offer the same variety of flavors — chocolate, fruit, cookie, caramel and more.',
#  '',
#  'What’s awesome about all these new options, these new “alternative” ice creams and desserts have made their way not only to the ice cream display on the storefront but into grocery stores too. Many name brand ice cream store chains also sell pints and tubs of ice creams in stores so you will be able to find dairy-free ice cream from Haagen-Dazs and Ben & Jerry’s. However, there are also numerous other brands that sell dairy free ice creams in stores that aren’t quite as well-known, such as Outshine, Coconut Bliss, Tofutti, and SO Delicious. You can experiment with all of these different brands and flavors to find which one hits the spot when you are sitting at home.',
#  'In the past eight months since I have gone dairy free, I have discovered numerous alternatives. There are now vegan ice creams, cashew ice creams, coconut ice creams, and even a to-die-for non-dairy, chocolate salted fudge truffle ice cream from Haagen-Dazs. The truth is that it has now become much easier for people who are allergic to dairy or who simply choose to refrain from it, like me, to find delicious alternatives to their favored dessert. You no longer need to give up a little bit of heaven in order to eat safely and maintain your diet choices. The wonderful world of dairy-free ice cream has only begun.',
#  '',
#  'Haagen-Dazs Non Dairy Flavors [list icon=”icon: check-square-o” icon_color=”#d81c5c”]',
#  '',
#  'Chocolate salted fudge truffle',
#  'Coconut Caramel',
#  'Coconut Cookies and Creme – Trio Crispy Layers',
#  'Crunchy Peanut Butter – Trio Crispy Layers',
#  'Mocha Chocolate Cookie',
#  'Peanut Butter Chocolate Fudge',
#  'Mango Sorbet',
#  'Peach Sorbet',
#  'Lemon Sorbet',
#  'Raspberry Sorbet',
#  'Cinnamon Buns',
#  'Peanut Butter Half Baked',
#  'Caramel Almond Brittle',
#  'Cherry Garcia',
#  'Chocolate Fudge Brownie',
#  'Chunky Monkey',
#  'Coconut Seven Layer Bar',
#  'Coffee Caramel Fudge',
#  'P.B. & Cookies',
#  '[list icon=”icon: check-square-o” icon_color=”#d81c5c”]',
#  'Berry Blend',
#  'Strawberry Banana',
#  'Sunrise Blend',
#  'Tropical Blend',
#  'I grew up avoiding a large quantity of dairy, for it had always aggravated my stomach, but it wasn’t until I had a hard time breathing during exercise that I gave up all dairy. There have been studies that show dairy can cause inflammation, so I believed by eliminating dairy from my diet it might reduce inflammation in my lungs. Not too long afterward, I also gave up gluten for the same reason. Although I came to learn that my difficulty breathing came from something called vocal cord dysfunction not asthma or inflammation in my lungs, I continued to follow a gluten and dairy free diet. I found that my energy was more consistent. I no longer felt like I went through random spikes and falls in energy. It helped my mood, and I felt more level emotionally. I had fewer stomach aches and nausea. All around, this new dairy and gluten and dairy free diet worked perfectly for me as an athlete. I have now been following this diet for close to eight months. This new diet has made me more passionate about awareness of allergens in the workplace and restaurants, the field my aunt works in, as I have seen first hand how hard it can be to order from a menu, and I am not allergic. I want people with all allergies and preferences to feel safe and comfortable with their diet, whether they are in the workplace or at a restaurant, or looking around a grocery store. There should be yummy food out there for everybody.']

# %%
split_rdd = rdd.flatMap(lambda x: x.split(' '))
words = split_rdd.collect()
words
# Out:
# Out[27]: ['Ever',
#  'since',
#  'my',
#  'first',
#  'lick',
#  'of',
#  'ice',
#  'cream,',
#  'it',
#  'has',
#  'been',
#  'an',
#  'endless',
#  'love',
#  'story.',
#  'Trading',
#  'my',
#  'toy',
#  'out',
#  'for',
#  'ice',
#  'cream',
#  'at',
#  'Chick-fil-a',
#  'was',
#  'the',
#  'easiest',
#  'decision',
#  'I',
#  'ever',
#  'had',
#  'to',
#  'make.',
#  'I',
#  'spent',
#  'every',
#  'spring,',
#  'summer,',
#  'fall,',
#  'and',
#  'winter',
#  'craving',
#  'ice',
#  'cream',
#  'when',
#  'I',
#  'was',
#  'happy,',
#  'sad',
#  'and',
#  'anywhere',
#  'in',
#  'between.',
#  'After',
#  'giving',
#  'up',
#  'dairy,',
#  'I',
#  'thought',
#  'my',
#  'long',
#  'and',
#  'faithful',
#  'love',
#  'story',
#  'with',
#  'ice',
#  'cream',
#  'had',
#  'come',
#  'crashing',
#  'to',
#  'an',
#  'end,',
#  'but',
#  'I',
#  'soon',
#  'realized',
#  'how',
#  'many',
#  'other',
#  'options',
#  'I',
#  'have.',
#  '',
#  'The',
#  'first',
#  'destination',
#  'on',
#  'my',
#  'road',
#  'to',
#  'discovering',
#  'dairy-free',
#  'ice',
#  'cream',
#  'options',
#  'landed',
#  'with',
#  'the',
#  'classic',
#  'sorbet.',
#  'This',
#  'dairy-',
#  'and',
#  'nut-free',
#  'option',
#  'is',
#  'also',
#  'free',
#  'of',
#  'most',
#  'common',
#  'allergens',
#  'while',
#  'maintaining',
#  'a',
#  'delicious',
#  'taste.',
#  'Sorbet',
#  'has',
#  'sat',
#  'back',
#  'seat',
#  'to',
#  'ice',
#  'cream',
#  'for',
#  'years,',
#  'but',
#  'at',
#  'almost',
#  'nearly',
#  'any',
#  'ice',
#  'cream',
#  'store',
#  'you',
#  'can',
#  'find',
#  'sorbet.',
#  'It’s',
#  'very',
#  'sweet,',
#  'so',
#  'it',
#  'easily',
#  'curbs',
#  'any',
#  'sweet',
#  'tooth.',
#  'While',
#  'it',
#  'might',
#  'not',
#  'be',
#  'quite',
#  'as',
#  'creamy',
#  'as',
#  'regular',
#  'ice',
#  'cream,',
#  'it’s',
#  'a',
#  'great',
#  'way',
#  'to',
#  'satiate',
#  'your',
#  'sugar',
#  'cravings',
#  'and',
#  'quench',
#  'your',
#  'thirst',
#  'at',
#  'the',
#  'same',
#  'time.',
#  '',
#  'One',
#  'of',
#  'the',
#  'things',
#  'that',
#  'made',
#  'me',
#  'fall',
#  'in',
#  'love',
#  'with',
#  'ice',
#  'cream',
#  'is',
#  'its',
#  'creamy',
#  'texture',
#  'that',
#  'melts',
#  'in',
#  'my',
#  'mouth.',
#  'Although',
#  'sorbet',
#  'may',
#  'not',
#  'feature',
#  'this,',
#  'there',
#  'are',
#  'numerous',
#  'vegan,',
#  'soy,',
#  'nut',
#  'and',
#  'coconut-based',
#  'ice',
#  'creams',
#  'that',
#  'provide',
#  'the',
#  'same',
#  'creamy',
#  'texture',
#  'and',
#  'offer',
#  'the',
#  'same',
#  'variety',
#  'of',
#  'flavors',
#  '—',
#  'chocolate,',
#  'fruit,',
#  'cookie,',
#  'caramel',
#  'and',
#  'more.',
#  '',
#  'What’s',
#  'awesome',
#  'about',
#  'all',
#  'these',
#  'new',
#  'options,',
#  'these',
#  'new',
#  '“alternative”',
#  'ice',
#  'creams',
#  'and',
#  'desserts',
#  'have',
#  'made',
#  'their',
#  'way',
#  'not',
#  'only',
#  'to',
#  'the',
#  'ice',
#  'cream',
#  'display',
#  'on',
#  'the',
#  'storefront',
#  'but',
#  'into',
#  'grocery',
#  'stores',
#  'too.',
#  'Many',
#  'name',
#  'brand',
#  'ice',
#  'cream',
#  'store',
#  'chains',
#  'also',
#  'sell',
#  'pints',
#  'and',
#  'tubs',
#  'of',
#  'ice',
#  'creams',
#  'in',
#  'stores',
#  'so',
#  'you',
#  'will',
#  'be',
#  'able',
#  'to',
#  'find',
#  'dairy-free',
#  'ice',
#  'cream',
#  'from',
#  'Haagen-Dazs',
#  'and',
#  'Ben',
#  '&',
#  'Jerry’s.',
#  'However,',
#  'there',
#  'are',
#  'also',
#  'numerous',
#  'other',
#  'brands',
#  'that',
#  'sell',
#  'dairy',
#  'free',
#  'ice',
#  'creams',
#  'in',
#  'stores',
#  'that',
#  'aren’t',
#  'quite',
#  'as',
#  'well-known,',
#  'such',
#  'as',
#  'Outshine,',
#  'Coconut',
#  'Bliss,',
#  'Tofutti,',
#  'and',
#  'SO',
#  'Delicious.',
#  'You',
#  'can',
#  'experiment',
#  'with',
#  'all',
#  'of',
#  'these',
#  'different',
#  'brands',
#  'and',
#  'flavors',
#  'to',
#  'find',
#  'which',
#  'one',
#  'hits',
#  'the',
#  'spot',
#  'when',
#  'you',
#  'are',
#  'sitting',
#  'at',
#  'home.',
#  'In',
#  'the',
#  'past',
#  'eight',
#  'months',
#  'since',
#  'I',
#  'have',
#  'gone',
#  'dairy',
#  'free,',
#  'I',
#  'have',
#  'discovered',
#  'numerous',
#  'alternatives.',
#  'There',
#  'are',
#  'now',
#  'vegan',
#  'ice',
#  'creams,',
#  'cashew',
#  'ice',
#  'creams,',
#  'coconut',
#  'ice',
#  'creams,',
#  'and',
#  'even',
#  'a',
#  'to-die-for',
#  'non-dairy,',
#  'chocolate',
#  'salted',
#  'fudge',
#  'truffle',
#  'ice',
#  'cream',
#  'from',
#  'Haagen-Dazs.',
#  'The',
#  'truth',
#  'is',
#  'that',
#  'it',
#  'has',
#  'now',
#  'become',
#  'much',
#  'easier',
#  'for',
#  'people',
#  'who',
#  'are',
#  'allergic',
#  'to',
#  'dairy',
#  'or',
#  'who',
#  'simply',
#  'choose',
#  'to',
#  'refrain',
#  'from',
#  'it,',
#  'like',
#  'me,',
#  'to',
#  'find',
#  'delicious',
#  'alternatives',
#  'to',
#  'their',
#  'favored',
#  'dessert.',
#  'You',
#  'no',
#  'longer',
#  'need',
#  'to',
#  'give',
#  'up',
#  'a',
#  'little',
#  'bit',
#  'of',
#  'heaven',
#  'in',
#  'order',
#  'to',
#  'eat',
#  'safely',
#  'and',
#  'maintain',
#  'your',
#  'diet',
#  'choices.',
#  'The',
#  'wonderful',
#  'world',
#  'of',
#  'dairy-free',
#  'ice',
#  'cream',
#  'has',
#  'only',
#  'begun.',
#  '',
#  'Haagen-Dazs',
#  'Non',
#  'Dairy',
#  'Flavors',
#  '[list',
#  'icon=”icon:',
#  'check-square-o”',
#  'icon_color=”#d81c5c”]',
#  '',
#  'Chocolate',
#  'salted',
#  'fudge',
#  'truffle',
#  'Coconut',
#  'Caramel',
#  'Coconut',
#  'Cookies',
#  'and',
#  'Creme',
#  '–',
#  'Trio',
#  'Crispy',
#  'Layers',
#  'Crunchy',
#  'Peanut',
#  'Butter',
#  '–',
#  'Trio',
#  'Crispy',
#  'Layers',
#  'Mocha',
#  'Chocolate',
#  'Cookie',
#  'Peanut',
#  'Butter',
#  'Chocolate',
#  'Fudge',
#  'Mango',
#  'Sorbet',
#  'Peach',
#  'Sorbet',
#  'Lemon',
#  'Sorbet',
#  'Raspberry',
#  'Sorbet',
#  'Cinnamon',
#  'Buns',
#  'Peanut',
#  'Butter',
#  'Half',
#  'Baked',
#  'Caramel',
#  'Almond',
#  'Brittle',
#  'Cherry',
#  'Garcia',
#  'Chocolate',
#  'Fudge',
#  'Brownie',
#  'Chunky',
#  'Monkey',
#  'Coconut',
#  'Seven',
#  'Layer',
#  'Bar',
#  'Coffee',
#  'Caramel',
#  'Fudge',
#  'P.B.',
#  '&',
#  'Cookies',
#  '[list',
#  'icon=”icon:',
#  'check-square-o”',
#  'icon_color=”#d81c5c”]',
#  'Berry',
#  'Blend',
#  'Strawberry',
#  'Banana',
#  'Sunrise',
#  'Blend',
#  'Tropical',
#  'Blend',
#  'I',
#  'grew',
#  'up',
#  'avoiding',
#  'a',
#  'large',
#  'quantity',
#  'of',
#  'dairy,',
#  'for',
#  'it',
#  'had',
#  'always',
#  'aggravated',
#  'my',
#  'stomach,',
#  'but',
#  'it',
#  'wasn’t',
#  'until',
#  'I',
#  'had',
#  'a',
#  'hard',
#  'time',
#  'breathing',
#  'during',
#  'exercise',
#  'that',
#  'I',
#  'gave',
#  'up',
#  'all',
#  'dairy.',
#  'There',
#  'have',
#  'been',
#  'studies',
#  'that',
#  'show',
#  'dairy',
#  'can',
#  'cause',
#  'inflammation,',
#  'so',
#  'I',
#  'believed',
#  'by',
#  'eliminating',
#  'dairy',
#  'from',
#  'my',
#  'diet',
#  'it',
#  'might',
#  'reduce',
#  'inflammation',
#  'in',
#  'my',
#  'lungs.',
#  'Not',
#  'too',
#  'long',
#  'afterward,',
#  'I',
#  'also',
#  'gave',
#  'up',
#  'gluten',
#  'for',
#  'the',
#  'same',
#  'reason.',
#  'Although',
#  'I',
#  'came',
#  'to',
#  'learn',
#  'that',
#  'my',
#  'difficulty',
#  'breathing',
#  'came',
#  'from',
#  'something',
#  'called',
#  'vocal',
#  'cord',
#  'dysfunction',
#  'not',
#  'asthma',
#  'or',
#  'inflammation',
#  'in',
#  'my',
#  'lungs,',
#  'I',
#  'continued',
#  'to',
#  'follow',
#  'a',
#  'gluten',
#  'and',
#  'dairy',
#  'free',
#  'diet.',
#  'I',
#  'found',
#  'that',
#  'my',
#  'energy',
#  'was',
#  'more',
#  'consistent.',
#  'I',
#  'no',
#  'longer',
#  'felt',
#  'like',
#  'I',
#  'went',
#  'through',
#  'random',
#  'spikes',
#  'and',
#  'falls',
#  'in',
#  'energy.',
#  'It',
#  'helped',
#  'my',
#  'mood,',
#  'and',
#  'I',
#  'felt',
#  'more',
#  'level',
#  'emotionally.',
#  'I',
#  'had',
#  'fewer',
#  'stomach',
#  'aches',
#  'and',
#  'nausea.',
#  'All',
#  'around,',
#  'this',
#  'new',
#  'dairy',
#  'and',
#  'gluten',
#  'and',
#  'dairy',
#  'free',
#  'diet',
#  'worked',
#  'perfectly',
#  'for',
#  'me',
#  'as',
#  'an',
#  'athlete.',
#  'I',
#  'have',
#  'now',
#  'been',
#  'following',
#  'this',
#  'diet',
#  'for',
#  'close',
#  'to',
#  'eight',
#  'months.',
#  'This',
#  'new',
#  'diet',
#  'has',
#  'made',
#  'me',
#  'more',
#  'passionate',
#  'about',
#  'awareness',
#  'of',
#  'allergens',
#  'in',
#  'the',
#  'workplace',
#  'and',
#  'restaurants,',
#  'the',
#  'field',
#  'my',
#  'aunt',
#  'works',
#  'in,',
#  'as',
#  'I',
#  'have',
#  'seen',
#  'first',
#  'hand',
#  'how',
#  'hard',
#  'it',
#  'can',
#  'be',
#  'to',
#  'order',
#  'from',
#  'a',
#  'menu,',
#  'and',
#  'I',
#  'am',
#  'not',
#  'allergic.',
#  'I',
#  'want',
#  'people',
#  'with',
#  'all',
#  'allergies',
#  'and',
#  'preferences',
#  'to',
#  'feel',
#  'safe',
#  'and',
#  'comfortable',
#  'with',
#  'their',
#  'diet,',
#  'whether',
#  'they',
#  'are',
#  'in',
#  'the',
#  'workplace',
#  'or',
#  'at',
#  'a',
#  'restaurant,',
#  'or',
#  'looking',
#  'around',
#  'a',
#  'grocery',
#  'store.',
#  'There',
#  'should',
#  'be',
#  'yummy',
#  'food',
#  'out',
#  'there',
#  'for',
#  'everybody.']

# %%
word_freq = split_rdd.map(lambda x: (x,1))
word_freq.collect()
# Out:
# Out[28]: [('Ever', 1),
#  ('since', 1),
#  ('my', 1),
#  ('first', 1),
#  ('lick', 1),
#  ('of', 1),
#  ('ice', 1),
#  ('cream,', 1),
#  ('it', 1),
#  ('has', 1),
#  ('been', 1),
#  ('an', 1),
#  ('endless', 1),
#  ('love', 1),
#  ('story.', 1),
#  ('Trading', 1),
#  ('my', 1),
#  ('toy', 1),
#  ('out', 1),
#  ('for', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('at', 1),
#  ('Chick-fil-a', 1),
#  ('was', 1),
#  ('the', 1),
#  ('easiest', 1),
#  ('decision', 1),
#  ('I', 1),
#  ('ever', 1),
#  ('had', 1),
#  ('to', 1),
#  ('make.', 1),
#  ('I', 1),
#  ('spent', 1),
#  ('every', 1),
#  ('spring,', 1),
#  ('summer,', 1),
#  ('fall,', 1),
#  ('and', 1),
#  ('winter', 1),
#  ('craving', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('when', 1),
#  ('I', 1),
#  ('was', 1),
#  ('happy,', 1),
#  ('sad', 1),
#  ('and', 1),
#  ('anywhere', 1),
#  ('in', 1),
#  ('between.', 1),
#  ('After', 1),
#  ('giving', 1),
#  ('up', 1),
#  ('dairy,', 1),
#  ('I', 1),
#  ('thought', 1),
#  ('my', 1),
#  ('long', 1),
#  ('and', 1),
#  ('faithful', 1),
#  ('love', 1),
#  ('story', 1),
#  ('with', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('had', 1),
#  ('come', 1),
#  ('crashing', 1),
#  ('to', 1),
#  ('an', 1),
#  ('end,', 1),
#  ('but', 1),
#  ('I', 1),
#  ('soon', 1),
#  ('realized', 1),
#  ('how', 1),
#  ('many', 1),
#  ('other', 1),
#  ('options', 1),
#  ('I', 1),
#  ('have.', 1),
#  ('', 1),
#  ('The', 1),
#  ('first', 1),
#  ('destination', 1),
#  ('on', 1),
#  ('my', 1),
#  ('road', 1),
#  ('to', 1),
#  ('discovering', 1),
#  ('dairy-free', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('options', 1),
#  ('landed', 1),
#  ('with', 1),
#  ('the', 1),
#  ('classic', 1),
#  ('sorbet.', 1),
#  ('This', 1),
#  ('dairy-', 1),
#  ('and', 1),
#  ('nut-free', 1),
#  ('option', 1),
#  ('is', 1),
#  ('also', 1),
#  ('free', 1),
#  ('of', 1),
#  ('most', 1),
#  ('common', 1),
#  ('allergens', 1),
#  ('while', 1),
#  ('maintaining', 1),
#  ('a', 1),
#  ('delicious', 1),
#  ('taste.', 1),
#  ('Sorbet', 1),
#  ('has', 1),
#  ('sat', 1),
#  ('back', 1),
#  ('seat', 1),
#  ('to', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('for', 1),
#  ('years,', 1),
#  ('but', 1),
#  ('at', 1),
#  ('almost', 1),
#  ('nearly', 1),
#  ('any', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('store', 1),
#  ('you', 1),
#  ('can', 1),
#  ('find', 1),
#  ('sorbet.', 1),
#  ('It’s', 1),
#  ('very', 1),
#  ('sweet,', 1),
#  ('so', 1),
#  ('it', 1),
#  ('easily', 1),
#  ('curbs', 1),
#  ('any', 1),
#  ('sweet', 1),
#  ('tooth.', 1),
#  ('While', 1),
#  ('it', 1),
#  ('might', 1),
#  ('not', 1),
#  ('be', 1),
#  ('quite', 1),
#  ('as', 1),
#  ('creamy', 1),
#  ('as', 1),
#  ('regular', 1),
#  ('ice', 1),
#  ('cream,', 1),
#  ('it’s', 1),
#  ('a', 1),
#  ('great', 1),
#  ('way', 1),
#  ('to', 1),
#  ('satiate', 1),
#  ('your', 1),
#  ('sugar', 1),
#  ('cravings', 1),
#  ('and', 1),
#  ('quench', 1),
#  ('your', 1),
#  ('thirst', 1),
#  ('at', 1),
#  ('the', 1),
#  ('same', 1),
#  ('time.', 1),
#  ('', 1),
#  ('One', 1),
#  ('of', 1),
#  ('the', 1),
#  ('things', 1),
#  ('that', 1),
#  ('made', 1),
#  ('me', 1),
#  ('fall', 1),
#  ('in', 1),
#  ('love', 1),
#  ('with', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('is', 1),
#  ('its', 1),
#  ('creamy', 1),
#  ('texture', 1),
#  ('that', 1),
#  ('melts', 1),
#  ('in', 1),
#  ('my', 1),
#  ('mouth.', 1),
#  ('Although', 1),
#  ('sorbet', 1),
#  ('may', 1),
#  ('not', 1),
#  ('feature', 1),
#  ('this,', 1),
#  ('there', 1),
#  ('are', 1),
#  ('numerous', 1),
#  ('vegan,', 1),
#  ('soy,', 1),
#  ('nut', 1),
#  ('and', 1),
#  ('coconut-based', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('that', 1),
#  ('provide', 1),
#  ('the', 1),
#  ('same', 1),
#  ('creamy', 1),
#  ('texture', 1),
#  ('and', 1),
#  ('offer', 1),
#  ('the', 1),
#  ('same', 1),
#  ('variety', 1),
#  ('of', 1),
#  ('flavors', 1),
#  ('—', 1),
#  ('chocolate,', 1),
#  ('fruit,', 1),
#  ('cookie,', 1),
#  ('caramel', 1),
#  ('and', 1),
#  ('more.', 1),
#  ('', 1),
#  ('What’s', 1),
#  ('awesome', 1),
#  ('about', 1),
#  ('all', 1),
#  ('these', 1),
#  ('new', 1),
#  ('options,', 1),
#  ('these', 1),
#  ('new', 1),
#  ('“alternative”', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('and', 1),
#  ('desserts', 1),
#  ('have', 1),
#  ('made', 1),
#  ('their', 1),
#  ('way', 1),
#  ('not', 1),
#  ('only', 1),
#  ('to', 1),
#  ('the', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('display', 1),
#  ('on', 1),
#  ('the', 1),
#  ('storefront', 1),
#  ('but', 1),
#  ('into', 1),
#  ('grocery', 1),
#  ('stores', 1),
#  ('too.', 1),
#  ('Many', 1),
#  ('name', 1),
#  ('brand', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('store', 1),
#  ('chains', 1),
#  ('also', 1),
#  ('sell', 1),
#  ('pints', 1),
#  ('and', 1),
#  ('tubs', 1),
#  ('of', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('in', 1),
#  ('stores', 1),
#  ('so', 1),
#  ('you', 1),
#  ('will', 1),
#  ('be', 1),
#  ('able', 1),
#  ('to', 1),
#  ('find', 1),
#  ('dairy-free', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('from', 1),
#  ('Haagen-Dazs', 1),
#  ('and', 1),
#  ('Ben', 1),
#  ('&', 1),
#  ('Jerry’s.', 1),
#  ('However,', 1),
#  ('there', 1),
#  ('are', 1),
#  ('also', 1),
#  ('numerous', 1),
#  ('other', 1),
#  ('brands', 1),
#  ('that', 1),
#  ('sell', 1),
#  ('dairy', 1),
#  ('free', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('in', 1),
#  ('stores', 1),
#  ('that', 1),
#  ('aren’t', 1),
#  ('quite', 1),
#  ('as', 1),
#  ('well-known,', 1),
#  ('such', 1),
#  ('as', 1),
#  ('Outshine,', 1),
#  ('Coconut', 1),
#  ('Bliss,', 1),
#  ('Tofutti,', 1),
#  ('and', 1),
#  ('SO', 1),
#  ('Delicious.', 1),
#  ('You', 1),
#  ('can', 1),
#  ('experiment', 1),
#  ('with', 1),
#  ('all', 1),
#  ('of', 1),
#  ('these', 1),
#  ('different', 1),
#  ('brands', 1),
#  ('and', 1),
#  ('flavors', 1),
#  ('to', 1),
#  ('find', 1),
#  ('which', 1),
#  ('one', 1),
#  ('hits', 1),
#  ('the', 1),
#  ('spot', 1),
#  ('when', 1),
#  ('you', 1),
#  ('are', 1),
#  ('sitting', 1),
#  ('at', 1),
#  ('home.', 1),
#  ('In', 1),
#  ('the', 1),
#  ('past', 1),
#  ('eight', 1),
#  ('months', 1),
#  ('since', 1),
#  ('I', 1),
#  ('have', 1),
#  ('gone', 1),
#  ('dairy', 1),
#  ('free,', 1),
#  ('I', 1),
#  ('have', 1),
#  ('discovered', 1),
#  ('numerous', 1),
#  ('alternatives.', 1),
#  ('There', 1),
#  ('are', 1),
#  ('now', 1),
#  ('vegan', 1),
#  ('ice', 1),
#  ('creams,', 1),
#  ('cashew', 1),
#  ('ice', 1),
#  ('creams,', 1),
#  ('coconut', 1),
#  ('ice', 1),
#  ('creams,', 1),
#  ('and', 1),
#  ('even', 1),
#  ('a', 1),
#  ('to-die-for', 1),
#  ('non-dairy,', 1),
#  ('chocolate', 1),
#  ('salted', 1),
#  ('fudge', 1),
#  ('truffle', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('from', 1),
#  ('Haagen-Dazs.', 1),
#  ('The', 1),
#  ('truth', 1),
#  ('is', 1),
#  ('that', 1),
#  ('it', 1),
#  ('has', 1),
#  ('now', 1),
#  ('become', 1),
#  ('much', 1),
#  ('easier', 1),
#  ('for', 1),
#  ('people', 1),
#  ('who', 1),
#  ('are', 1),
#  ('allergic', 1),
#  ('to', 1),
#  ('dairy', 1),
#  ('or', 1),
#  ('who', 1),
#  ('simply', 1),
#  ('choose', 1),
#  ('to', 1),
#  ('refrain', 1),
#  ('from', 1),
#  ('it,', 1),
#  ('like', 1),
#  ('me,', 1),
#  ('to', 1),
#  ('find', 1),
#  ('delicious', 1),
#  ('alternatives', 1),
#  ('to', 1),
#  ('their', 1),
#  ('favored', 1),
#  ('dessert.', 1),
#  ('You', 1),
#  ('no', 1),
#  ('longer', 1),
#  ('need', 1),
#  ('to', 1),
#  ('give', 1),
#  ('up', 1),
#  ('a', 1),
#  ('little', 1),
#  ('bit', 1),
#  ('of', 1),
#  ('heaven', 1),
#  ('in', 1),
#  ('order', 1),
#  ('to', 1),
#  ('eat', 1),
#  ('safely', 1),
#  ('and', 1),
#  ('maintain', 1),
#  ('your', 1),
#  ('diet', 1),
#  ('choices.', 1),
#  ('The', 1),
#  ('wonderful', 1),
#  ('world', 1),
#  ('of', 1),
#  ('dairy-free', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('has', 1),
#  ('only', 1),
#  ('begun.', 1),
#  ('', 1),
#  ('Haagen-Dazs', 1),
#  ('Non', 1),
#  ('Dairy', 1),
#  ('Flavors', 1),
#  ('[list', 1),
#  ('icon=”icon:', 1),
#  ('check-square-o”', 1),
#  ('icon_color=”#d81c5c”]', 1),
#  ('', 1),
#  ('Chocolate', 1),
#  ('salted', 1),
#  ('fudge', 1),
#  ('truffle', 1),
#  ('Coconut', 1),
#  ('Caramel', 1),
#  ('Coconut', 1),
#  ('Cookies', 1),
#  ('and', 1),
#  ('Creme', 1),
#  ('–', 1),
#  ('Trio', 1),
#  ('Crispy', 1),
#  ('Layers', 1),
#  ('Crunchy', 1),
#  ('Peanut', 1),
#  ('Butter', 1),
#  ('–', 1),
#  ('Trio', 1),
#  ('Crispy', 1),
#  ('Layers', 1),
#  ('Mocha', 1),
#  ('Chocolate', 1),
#  ('Cookie', 1),
#  ('Peanut', 1),
#  ('Butter', 1),
#  ('Chocolate', 1),
#  ('Fudge', 1),
#  ('Mango', 1),
#  ('Sorbet', 1),
#  ('Peach', 1),
#  ('Sorbet', 1),
#  ('Lemon', 1),
#  ('Sorbet', 1),
#  ('Raspberry', 1),
#  ('Sorbet', 1),
#  ('Cinnamon', 1),
#  ('Buns', 1),
#  ('Peanut', 1),
#  ('Butter', 1),
#  ('Half', 1),
#  ('Baked', 1),
#  ('Caramel', 1),
#  ('Almond', 1),
#  ('Brittle', 1),
#  ('Cherry', 1),
#  ('Garcia', 1),
#  ('Chocolate', 1),
#  ('Fudge', 1),
#  ('Brownie', 1),
#  ('Chunky', 1),
#  ('Monkey', 1),
#  ('Coconut', 1),
#  ('Seven', 1),
#  ('Layer', 1),
#  ('Bar', 1),
#  ('Coffee', 1),
#  ('Caramel', 1),
#  ('Fudge', 1),
#  ('P.B.', 1),
#  ('&', 1),
#  ('Cookies', 1),
#  ('[list', 1),
#  ('icon=”icon:', 1),
#  ('check-square-o”', 1),
#  ('icon_color=”#d81c5c”]', 1),
#  ('Berry', 1),
#  ('Blend', 1),
#  ('Strawberry', 1),
#  ('Banana', 1),
#  ('Sunrise', 1),
#  ('Blend', 1),
#  ('Tropical', 1),
#  ('Blend', 1),
#  ('I', 1),
#  ('grew', 1),
#  ('up', 1),
#  ('avoiding', 1),
#  ('a', 1),
#  ('large', 1),
#  ('quantity', 1),
#  ('of', 1),
#  ('dairy,', 1),
#  ('for', 1),
#  ('it', 1),
#  ('had', 1),
#  ('always', 1),
#  ('aggravated', 1),
#  ('my', 1),
#  ('stomach,', 1),
#  ('but', 1),
#  ('it', 1),
#  ('wasn’t', 1),
#  ('until', 1),
#  ('I', 1),
#  ('had', 1),
#  ('a', 1),
#  ('hard', 1),
#  ('time', 1),
#  ('breathing', 1),
#  ('during', 1),
#  ('exercise', 1),
#  ('that', 1),
#  ('I', 1),
#  ('gave', 1),
#  ('up', 1),
#  ('all', 1),
#  ('dairy.', 1),
#  ('There', 1),
#  ('have', 1),
#  ('been', 1),
#  ('studies', 1),
#  ('that', 1),
#  ('show', 1),
#  ('dairy', 1),
#  ('can', 1),
#  ('cause', 1),
#  ('inflammation,', 1),
#  ('so', 1),
#  ('I', 1),
#  ('believed', 1),
#  ('by', 1),
#  ('eliminating', 1),
#  ('dairy', 1),
#  ('from', 1),
#  ('my', 1),
#  ('diet', 1),
#  ('it', 1),
#  ('might', 1),
#  ('reduce', 1),
#  ('inflammation', 1),
#  ('in', 1),
#  ('my', 1),
#  ('lungs.', 1),
#  ('Not', 1),
#  ('too', 1),
#  ('long', 1),
#  ('afterward,', 1),
#  ('I', 1),
#  ('also', 1),
#  ('gave', 1),
#  ('up', 1),
#  ('gluten', 1),
#  ('for', 1),
#  ('the', 1),
#  ('same', 1),
#  ('reason.', 1),
#  ('Although', 1),
#  ('I', 1),
#  ('came', 1),
#  ('to', 1),
#  ('learn', 1),
#  ('that', 1),
#  ('my', 1),
#  ('difficulty', 1),
#  ('breathing', 1),
#  ('came', 1),
#  ('from', 1),
#  ('something', 1),
#  ('called', 1),
#  ('vocal', 1),
#  ('cord', 1),
#  ('dysfunction', 1),
#  ('not', 1),
#  ('asthma', 1),
#  ('or', 1),
#  ('inflammation', 1),
#  ('in', 1),
#  ('my', 1),
#  ('lungs,', 1),
#  ('I', 1),
#  ('continued', 1),
#  ('to', 1),
#  ('follow', 1),
#  ('a', 1),
#  ('gluten', 1),
#  ('and', 1),
#  ('dairy', 1),
#  ('free', 1),
#  ('diet.', 1),
#  ('I', 1),
#  ('found', 1),
#  ('that', 1),
#  ('my', 1),
#  ('energy', 1),
#  ('was', 1),
#  ('more', 1),
#  ('consistent.', 1),
#  ('I', 1),
#  ('no', 1),
#  ('longer', 1),
#  ('felt', 1),
#  ('like', 1),
#  ('I', 1),
#  ('went', 1),
#  ('through', 1),
#  ('random', 1),
#  ('spikes', 1),
#  ('and', 1),
#  ('falls', 1),
#  ('in', 1),
#  ('energy.', 1),
#  ('It', 1),
#  ('helped', 1),
#  ('my', 1),
#  ('mood,', 1),
#  ('and', 1),
#  ('I', 1),
#  ('felt', 1),
#  ('more', 1),
#  ('level', 1),
#  ('emotionally.', 1),
#  ('I', 1),
#  ('had', 1),
#  ('fewer', 1),
#  ('stomach', 1),
#  ('aches', 1),
#  ('and', 1),
#  ('nausea.', 1),
#  ('All', 1),
#  ('around,', 1),
#  ('this', 1),
#  ('new', 1),
#  ('dairy', 1),
#  ('and', 1),
#  ('gluten', 1),
#  ('and', 1),
#  ('dairy', 1),
#  ('free', 1),
#  ('diet', 1),
#  ('worked', 1),
#  ('perfectly', 1),
#  ('for', 1),
#  ('me', 1),
#  ('as', 1),
#  ('an', 1),
#  ('athlete.', 1),
#  ('I', 1),
#  ('have', 1),
#  ('now', 1),
#  ('been', 1),
#  ('following', 1),
#  ('this', 1),
#  ('diet', 1),
#  ('for', 1),
#  ('close', 1),
#  ('to', 1),
#  ('eight', 1),
#  ('months.', 1),
#  ('This', 1),
#  ('new', 1),
#  ('diet', 1),
#  ('has', 1),
#  ('made', 1),
#  ('me', 1),
#  ('more', 1),
#  ('passionate', 1),
#  ('about', 1),
#  ('awareness', 1),
#  ('of', 1),
#  ('allergens', 1),
#  ('in', 1),
#  ('the', 1),
#  ('workplace', 1),
#  ('and', 1),
#  ('restaurants,', 1),
#  ('the', 1),
#  ('field', 1),
#  ('my', 1),
#  ('aunt', 1),
#  ('works', 1),
#  ('in,', 1),
#  ('as', 1),
#  ('I', 1),
#  ('have', 1),
#  ('seen', 1),
#  ('first', 1),
#  ('hand', 1),
#  ('how', 1),
#  ('hard', 1),
#  ('it', 1),
#  ('can', 1),
#  ('be', 1),
#  ('to', 1),
#  ('order', 1),
#  ('from', 1),
#  ('a', 1),
#  ('menu,', 1),
#  ('and', 1),
#  ('I', 1),
#  ('am', 1),
#  ('not', 1),
#  ('allergic.', 1),
#  ('I', 1),
#  ('want', 1),
#  ('people', 1),
#  ('with', 1),
#  ('all', 1),
#  ('allergies', 1),
#  ('and', 1),
#  ('preferences', 1),
#  ('to', 1),
#  ('feel', 1),
#  ('safe', 1),
#  ('and', 1),
#  ('comfortable', 1),
#  ('with', 1),
#  ('their', 1),
#  ('diet,', 1),
#  ('whether', 1),
#  ('they', 1),
#  ('are', 1),
#  ('in', 1),
#  ('the', 1),
#  ('workplace', 1),
#  ('or', 1),
#  ('at', 1),
#  ('a', 1),
#  ('restaurant,', 1),
#  ('or', 1),
#  ('looking', 1),
#  ('around', 1),
#  ('a', 1),
#  ('grocery', 1),
#  ('store.', 1),
#  ('There', 1),
#  ('should', 1),
#  ('be', 1),
#  ('yummy', 1),
#  ('food', 1),
#  ('out', 1),
#  ('there', 1),
#  ('for', 1),
#  ('everybody.', 1)]

# %%
count_rdd = word_freq.reduceByKey(lambda a,b: a+b)
count_rdd.collect()
# Out:
# Out[29]: [('of', 10),
#  ('ice', 21),
#  ('cream,', 2),
#  ('an', 3),
#  ('love', 3),
#  ('out', 2),
#  ('cream', 12),
#  ('at', 5),
#  ('Chick-fil-a', 1),
#  ('was', 3),
#  ('decision', 1),
#  ('ever', 1),
#  ('make.', 1),
#  ('fall,', 1),
#  ('when', 2),
#  ('happy,', 1),
#  ('sad', 1),
#  ('anywhere', 1),
#  ('in', 11),
#  ('thought', 1),
#  ('long', 2),
#  ('faithful', 1),
#  ('story', 1),
#  ('crashing', 1),
#  ('end,', 1),
#  ('but', 4),
#  ('realized', 1),
#  ('other', 2),
#  ('options', 2),
#  ('have.', 1),
#  ('', 5),
#  ('The', 3),
#  ('destination', 1),
#  ('road', 1),
#  ('sorbet.', 2),
#  ('is', 3),
#  ('free', 4),
#  ('common', 1),
#  ('allergens', 2),
#  ('maintaining', 1),
#  ('taste.', 1),
#  ('sat', 1),
#  ('years,', 1),
#  ('store', 2),
#  ('It’s', 1),
#  ('very', 1),
#  ('sweet,', 1),
#  ('easily', 1),
#  ('curbs', 1),
#  ('sweet', 1),
#  ('tooth.', 1),
#  ('quite', 2),
#  ('as', 6),
#  ('regular', 1),
#  ('it’s', 1),
#  ('way', 2),
#  ('sugar', 1),
#  ('thirst', 1),
#  ('One', 1),
#  ('things', 1),
#  ('fall', 1),
#  ('may', 1),
#  ('feature', 1),
#  ('this,', 1),
#  ('there', 3),
#  ('are', 6),
#  ('soy,', 1),
#  ('nut', 1),
#  ('coconut-based', 1),
#  ('provide', 1),
#  ('cookie,', 1),
#  ('awesome', 1),
#  ('these', 3),
#  ('new', 4),
#  ('options,', 1),
#  ('“alternative”', 1),
#  ('desserts', 1),
#  ('have', 6),
#  ('only', 2),
#  ('storefront', 1),
#  ('into', 1),
#  ('stores', 3),
#  ('too.', 1),
#  ('name', 1),
#  ('brand', 1),
#  ('pints', 1),
#  ('able', 1),
#  ('Haagen-Dazs', 2),
#  ('Ben', 1),
#  ('However,', 1),
#  ('dairy', 8),
#  ('aren’t', 1),
#  ('Outshine,', 1),
#  ('Bliss,', 1),
#  ('Delicious.', 1),
#  ('experiment', 1),
#  ('different', 1),
#  ('spot', 1),
#  ('sitting', 1),
#  ('home.', 1),
#  ('past', 1),
#  ('eight', 2),
#  ('months', 1),
#  ('free,', 1),
#  ('alternatives.', 1),
#  ('now', 3),
#  ('creams,', 3),
#  ('cashew', 1),
#  ('coconut', 1),
#  ('even', 1),
#  ('to-die-for', 1),
#  ('non-dairy,', 1),
#  ('chocolate', 1),
#  ('truffle', 2),
#  ('become', 1),
#  ('refrain', 1),
#  ('it,', 1),
#  ('like', 2),
#  ('alternatives', 1),
#  ('no', 2),
#  ('longer', 2),
#  ('give', 1),
#  ('safely', 1),
#  ('maintain', 1),
#  ('choices.', 1),
#  ('wonderful', 1),
#  ('world', 1),
#  ('begun.', 1),
#  ('Non', 1),
#  ('Flavors', 1),
#  ('[list', 2),
#  ('icon=”icon:', 2),
#  ('icon_color=”#d81c5c”]', 2),
#  ('Chocolate', 4),
#  ('Caramel', 3),
#  ('Crispy', 2),
#  ('Layers', 2),
#  ('Crunchy', 1),
#  ('Butter', 3),
#  ('Fudge', 3),
#  ('Cinnamon', 1),
#  ('Half', 1),
#  ('Almond', 1),
#  ('Brittle', 1),
#  ('Cherry', 1),
#  ('Garcia', 1),
#  ('Bar', 1),
#  ('P.B.', 1),
#  ('Berry', 1),
#  ('Strawberry', 1),
#  ('avoiding', 1),
#  ('large', 1),
#  ('always', 1),
#  ('aggravated', 1),
#  ('until', 1),
#  ('during', 1),
#  ('exercise', 1),
#  ('gave', 2),
#  ('studies', 1),
#  ('cause', 1),
#  ('believed', 1),
#  ('eliminating', 1),
#  ('reduce', 1),
#  ('inflammation', 2),
#  ('Not', 1),
#  ('afterward,', 1),
#  ('came', 2),
#  ('difficulty', 1),
#  ('something', 1),
#  ('vocal', 1),
#  ('cord', 1),
#  ('dysfunction', 1),
#  ('lungs,', 1),
#  ('continued', 1),
#  ('diet.', 1),
#  ('more', 3),
#  ('felt', 2),
#  ('falls', 1),
#  ('It', 1),
#  ('fewer', 1),
#  ('aches', 1),
#  ('nausea.', 1),
#  ('this', 2),
#  ('worked', 1),
#  ('perfectly', 1),
#  ('following', 1),
#  ('close', 1),
#  ('months.', 1),
#  ('passionate', 1),
#  ('restaurants,', 1),
#  ('field', 1),
#  ('seen', 1),
#  ('am', 1),
#  ('allergic.', 1),
#  ('preferences', 1),
#  ('feel', 1),
#  ('safe', 1),
#  ('comfortable', 1),
#  ('looking', 1),
#  ('around', 1),
#  ('yummy', 1),
#  ('everybody.', 1),
#  ('Ever', 1),
#  ('since', 2),
#  ('my', 13),
#  ('first', 3),
#  ('lick', 1),
#  ('it', 8),
#  ('has', 5),
#  ('been', 3),
#  ('endless', 1),
#  ('story.', 1),
#  ('Trading', 1),
#  ('toy', 1),
#  ('for', 8),
#  ('the', 14),
#  ('easiest', 1),
#  ('I', 24),
#  ('had', 5),
#  ('to', 19),
#  ('spent', 1),
#  ('every', 1),
#  ('spring,', 1),
#  ('summer,', 1),
#  ('and', 26),
#  ('winter', 1),
#  ('craving', 1),
#  ('between.', 1),
#  ('After', 1),
#  ('giving', 1),
#  ('up', 5),
#  ('dairy,', 2),
#  ('with', 6),
#  ('come', 1),
#  ('soon', 1),
#  ('how', 2),
#  ('many', 1),
#  ('on', 2),
#  ('discovering', 1),
#  ('dairy-free', 3),
#  ('landed', 1),
#  ('classic', 1),
#  ('This', 2),
#  ('dairy-', 1),
#  ('nut-free', 1),
#  ('option', 1),
#  ('also', 4),
#  ('most', 1),
#  ('while', 1),
#  ('a', 10),
#  ('delicious', 2),
#  ('Sorbet', 5),
#  ('back', 1),
#  ('seat', 1),
#  ('almost', 1),
#  ('nearly', 1),
#  ('any', 2),
#  ('you', 3),
#  ('can', 4),
#  ('find', 4),
#  ('so', 3),
#  ('While', 1),
#  ('might', 2),
#  ('not', 5),
#  ('be', 4),
#  ('creamy', 3),
#  ('great', 1),
#  ('satiate', 1),
#  ('your', 3),
#  ('cravings', 1),
#  ('quench', 1),
#  ('same', 4),
#  ('time.', 1),
#  ('that', 10),
#  ('made', 3),
#  ('me', 3),
#  ('its', 1),
#  ('texture', 2),
#  ('melts', 1),
#  ('mouth.', 1),
#  ('Although', 2),
#  ('sorbet', 1),
#  ('numerous', 3),
#  ('vegan,', 1),
#  ('creams', 4),
#  ('offer', 1),
#  ('variety', 1),
#  ('flavors', 2),
#  ('—', 1),
#  ('chocolate,', 1),
#  ('fruit,', 1),
#  ('caramel', 1),
#  ('more.', 1),
#  ('What’s', 1),
#  ('about', 2),
#  ('all', 4),
#  ('their', 3),
#  ('display', 1),
#  ('grocery', 2),
#  ('Many', 1),
#  ('chains', 1),
#  ('sell', 2),
#  ('tubs', 1),
#  ('will', 1),
#  ('from', 6),
#  ('&', 2),
#  ('Jerry’s.', 1),
#  ('brands', 2),
#  ('well-known,', 1),
#  ('such', 1),
#  ('Coconut', 4),
#  ('Tofutti,', 1),
#  ('SO', 1),
#  ('You', 2),
#  ('which', 1),
#  ('one', 1),
#  ('hits', 1),
#  ('In', 1),
#  ('gone', 1),
#  ('discovered', 1),
#  ('There', 3),
#  ('vegan', 1),
#  ('salted', 2),
#  ('fudge', 2),
#  ('Haagen-Dazs.', 1),
#  ('truth', 1),
#  ('much', 1),
#  ('easier', 1),
#  ('people', 2),
#  ('who', 2),
#  ('allergic', 1),
#  ('or', 4),
#  ('simply', 1),
#  ('choose', 1),
#  ('me,', 1),
#  ('favored', 1),
#  ('dessert.', 1),
#  ('need', 1),
#  ('little', 1),
#  ('bit', 1),
#  ('heaven', 1),
#  ('order', 2),
#  ('eat', 1),
#  ('diet', 5),
#  ('Dairy', 1),
#  ('check-square-o”', 2),
#  ('Cookies', 2),
#  ('Creme', 1),
#  ('–', 2),
#  ('Trio', 2),
#  ('Peanut', 3),
#  ('Mocha', 1),
#  ('Cookie', 1),
#  ('Mango', 1),
#  ('Peach', 1),
#  ('Lemon', 1),
#  ('Raspberry', 1),
#  ('Buns', 1),
#  ('Baked', 1),
#  ('Brownie', 1),
#  ('Chunky', 1),
#  ('Monkey', 1),
#  ('Seven', 1),
#  ('Layer', 1),
#  ('Coffee', 1),
#  ('Blend', 3),
#  ('Banana', 1),
#  ('Sunrise', 1),
#  ('Tropical', 1),
#  ('grew', 1),
#  ('quantity', 1),
#  ('stomach,', 1),
#  ('wasn’t', 1),
#  ('hard', 2),
#  ('time', 1),
#  ('breathing', 2),
#  ('dairy.', 1),
#  ('show', 1),
#  ('inflammation,', 1),
#  ('by', 1),
#  ('lungs.', 1),
#  ('too', 1),
#  ('gluten', 3),
#  ('reason.', 1),
#  ('learn', 1),
#  ('called', 1),
#  ('asthma', 1),
#  ('follow', 1),
#  ('found', 1),
#  ('energy', 1),
#  ('consistent.', 1),
#  ('went', 1),
#  ('through', 1),
#  ('random', 1),
#  ('spikes', 1),
#  ('energy.', 1),
#  ('helped', 1),
#  ('mood,', 1),
#  ('level', 1),
#  ('emotionally.', 1),
#  ('stomach', 1),
#  ('All', 1),
#  ('around,', 1),
#  ('athlete.', 1),
#  ('awareness', 1),
#  ('workplace', 2),
#  ('aunt', 1),
#  ('works', 1),
#  ('in,', 1),
#  ('hand', 1),
#  ('menu,', 1),
#  ('want', 1),
#  ('allergies', 1),
#  ('diet,', 1),
#  ('whether', 1),
#  ('they', 1),
#  ('restaurant,', 1),
#  ('store.', 1),
#  ('should', 1),
#  ('food', 1)]

# %%
rdd_sorted = count_rdd.map(lambda x: (x[1],x[0])).sortByKey()
rdd_sorted
# Out:
# Out[30]: PythonRDD[41] at RDD at PythonRDD.scala:58

# %%
first_ten = count_rdd.take(10)
for f in first_ten:
    print(f" : {f[0]} Value: {f[1]} ")
# Out:
#  : of Value: 10
#  : ice Value: 21
#  : cream, Value: 2
#  : an Value: 3
#  : love Value: 3
#  : out Value: 2
#  : cream Value: 12
#  : at Value: 5
#  : Chick-fil-a Value: 1
#  : was Value: 3

# %%
total_words = rdd_sorted.reduce(lambda a,b: (a[0]+b[0],a[1]))
print(f"Total Words : {total_words[0]} ")
# Out:
# Total Words : 811

# %%
data = rdd.collect()
data
# Out:
# Out[33]: ['Ever since my first lick of ice cream, it has been an endless love story. Trading my toy out for ice cream at Chick-fil-a was the easiest decision I ever had to make. I spent every spring, summer, fall, and winter craving ice cream when I was happy, sad and anywhere in between. After giving up dairy, I thought my long and faithful love story with ice cream had come crashing to an end, but I soon realized how many other options I have.',
#  '',
#  'The first destination on my road to discovering dairy-free ice cream options landed with the classic sorbet. This dairy- and nut-free option is also free of most common allergens while maintaining a delicious taste. Sorbet has sat back seat to ice cream for years, but at almost nearly any ice cream store you can find sorbet. It’s very sweet, so it easily curbs any sweet tooth. While it might not be quite as creamy as regular ice cream, it’s a great way to satiate your sugar cravings and quench your thirst at the same time.',
#  '',
#  'One of the things that made me fall in love with ice cream is its creamy texture that melts in my mouth. Although sorbet may not feature this, there are numerous vegan, soy, nut and coconut-based ice creams that provide the same creamy texture and offer the same variety of flavors — chocolate, fruit, cookie, caramel and more.',
#  '',
#  'What’s awesome about all these new options, these new “alternative” ice creams and desserts have made their way not only to the ice cream display on the storefront but into grocery stores too. Many name brand ice cream store chains also sell pints and tubs of ice creams in stores so you will be able to find dairy-free ice cream from Haagen-Dazs and Ben & Jerry’s. However, there are also numerous other brands that sell dairy free ice creams in stores that aren’t quite as well-known, such as Outshine, Coconut Bliss, Tofutti, and SO Delicious. You can experiment with all of these different brands and flavors to find which one hits the spot when you are sitting at home.',
#  'In the past eight months since I have gone dairy free, I have discovered numerous alternatives. There are now vegan ice creams, cashew ice creams, coconut ice creams, and even a to-die-for non-dairy, chocolate salted fudge truffle ice cream from Haagen-Dazs. The truth is that it has now become much easier for people who are allergic to dairy or who simply choose to refrain from it, like me, to find delicious alternatives to their favored dessert. You no longer need to give up a little bit of heaven in order to eat safely and maintain your diet choices. The wonderful world of dairy-free ice cream has only begun.',
#  '',
#  'Haagen-Dazs Non Dairy Flavors [list icon=”icon: check-square-o” icon_color=”#d81c5c”]',
#  '',
#  'Chocolate salted fudge truffle',
#  'Coconut Caramel',
#  'Coconut Cookies and Creme – Trio Crispy Layers',
#  'Crunchy Peanut Butter – Trio Crispy Layers',
#  'Mocha Chocolate Cookie',
#  'Peanut Butter Chocolate Fudge',
#  'Mango Sorbet',
#  'Peach Sorbet',
#  'Lemon Sorbet',
#  'Raspberry Sorbet',
#  'Cinnamon Buns',
#  'Peanut Butter Half Baked',
#  'Caramel Almond Brittle',
#  'Cherry Garcia',
#  'Chocolate Fudge Brownie',
#  'Chunky Monkey',
#  'Coconut Seven Layer Bar',
#  'Coffee Caramel Fudge',
#  'P.B. & Cookies',
#  '[list icon=”icon: check-square-o” icon_color=”#d81c5c”]',
#  'Berry Blend',
#  'Strawberry Banana',
#  'Sunrise Blend',
#  'Tropical Blend',
#  'I grew up avoiding a large quantity of dairy, for it had always aggravated my stomach, but it wasn’t until I had a hard time breathing during exercise that I gave up all dairy. There have been studies that show dairy can cause inflammation, so I believed by eliminating dairy from my diet it might reduce inflammation in my lungs. Not too long afterward, I also gave up gluten for the same reason. Although I came to learn that my difficulty breathing came from something called vocal cord dysfunction not asthma or inflammation in my lungs, I continued to follow a gluten and dairy free diet. I found that my energy was more consistent. I no longer felt like I went through random spikes and falls in energy. It helped my mood, and I felt more level emotionally. I had fewer stomach aches and nausea. All around, this new dairy and gluten and dairy free diet worked perfectly for me as an athlete. I have now been following this diet for close to eight months. This new diet has made me more passionate about awareness of allergens in the workplace and restaurants, the field my aunt works in, as I have seen first hand how hard it can be to order from a menu, and I am not allergic. I want people with all allergies and preferences to feel safe and comfortable with their diet, whether they are in the workplace or at a restaurant, or looking around a grocery store. There should be yummy food out there for everybody.']

# %%
import re
pattern = r'[\n\s!@#$%^&*\(\)\{\}\[\]~`/\?<>,\.]+'
words = re.split(pattern, str(data))
words
# Out:
# Out[34]: ['',
#  "'Ever",
#  'since',
#  'my',
#  'first',
#  'lick',
#  'of',
#  'ice',
#  'cream',
#  'it',
#  'has',
#  'been',
#  'an',
#  'endless',
#  'love',
#  'story',
#  'Trading',
#  'my',
#  'toy',
#  'out',
#  'for',
#  'ice',
#  'cream',
#  'at',
#  'Chick-fil-a',
#  'was',
#  'the',
#  'easiest',
#  'decision',
#  'I',
#  'ever',
#  'had',
#  'to',
#  'make',
#  'I',
#  'spent',
#  'every',
#  'spring',
#  'summer',
#  'fall',
#  'and',
#  'winter',
#  'craving',
#  'ice',
#  'cream',
#  'when',
#  'I',
#  'was',
#  'happy',
#  'sad',
#  'and',
#  'anywhere',
#  'in',
#  'between',
#  'After',
#  'giving',
#  'up',
#  'dairy',
#  'I',
#  'thought',
#  'my',
#  'long',
#  'and',
#  'faithful',
#  'love',
#  'story',
#  'with',
#  'ice',
#  'cream',
#  'had',
#  'come',
#  'crashing',
#  'to',
#  'an',
#  'end',
#  'but',
#  'I',
#  'soon',
#  'realized',
#  'how',
#  'many',
#  'other',
#  'options',
#  'I',
#  'have',
#  "'",
#  "''",
#  "'The",
#  'first',
#  'destination',
#  'on',
#  'my',
#  'road',
#  'to',
#  'discovering',
#  'dairy-free',
#  'ice',
#  'cream',
#  'options',
#  'landed',
#  'with',
#  'the',
#  'classic',
#  'sorbet',
#  'This',
#  'dairy-',
#  'and',
#  'nut-free',
#  'option',
#  'is',
#  'also',
#  'free',
#  'of',
#  'most',
#  'common',
#  'allergens',
#  'while',
#  'maintaining',
#  'a',
#  'delicious',
#  'taste',
#  'Sorbet',
#  'has',
#  'sat',
#  'back',
#  'seat',
#  'to',
#  'ice',
#  'cream',
#  'for',
#  'years',
#  'but',
#  'at',
#  'almost',
#  'nearly',
#  'any',
#  'ice',
#  'cream',
#  'store',
#  'you',
#  'can',
#  'find',
#  'sorbet',
#  'It’s',
#  'very',
#  'sweet',
#  'so',
#  'it',
#  'easily',
#  'curbs',
#  'any',
#  'sweet',
#  'tooth',
#  'While',
#  'it',
#  'might',
#  'not',
#  'be',
#  'quite',
#  'as',
#  'creamy',
#  'as',
#  'regular',
#  'ice',
#  'cream',
#  'it’s',
#  'a',
#  'great',
#  'way',
#  'to',
#  'satiate',
#  'your',
#  'sugar',
#  'cravings',
#  'and',
#  'quench',
#  'your',
#  'thirst',
#  'at',
#  'the',
#  'same',
#  'time',
#  "'",
#  "''",
#  "'One",
#  'of',
#  'the',
#  'things',
#  'that',
#  'made',
#  'me',
#  'fall',
#  'in',
#  'love',
#  'with',
#  'ice',
#  'cream',
#  'is',
#  'its',
#  'creamy',
#  'texture',
#  'that',
#  'melts',
#  'in',
#  'my',
#  'mouth',
#  'Although',
#  'sorbet',
#  'may',
#  'not',
#  'feature',
#  'this',
#  'there',
#  'are',
#  'numerous',
#  'vegan',
#  'soy',
#  'nut',
#  'and',
#  'coconut-based',
#  'ice',
#  'creams',
#  'that',
#  'provide',
#  'the',
#  'same',
#  'creamy',
#  'texture',
#  'and',
#  'offer',
#  'the',
#  'same',
#  'variety',
#  'of',
#  'flavors',
#  '—',
#  'chocolate',
#  'fruit',
#  'cookie',
#  'caramel',
#  'and',
#  'more',
#  "'",
#  "''",
#  "'What’s",
#  'awesome',
#  'about',
#  'all',
#  'these',
#  'new',
#  'options',
#  'these',
#  'new',
#  '“alternative”',
#  'ice',
#  'creams',
#  'and',
#  'desserts',
#  'have',
#  'made',
#  'their',
#  'way',
#  'not',
#  'only',
#  'to',
#  'the',
#  'ice',
#  'cream',
#  'display',
#  'on',
#  'the',
#  'storefront',
#  'but',
#  'into',
#  'grocery',
#  'stores',
#  'too',
#  'Many',
#  'name',
#  'brand',
#  'ice',
#  'cream',
#  'store',
#  'chains',
#  'also',
#  'sell',
#  'pints',
#  'and',
#  'tubs',
#  'of',
#  'ice',
#  'creams',
#  'in',
#  'stores',
#  'so',
#  'you',
#  'will',
#  'be',
#  'able',
#  'to',
#  'find',
#  'dairy-free',
#  'ice',
#  'cream',
#  'from',
#  'Haagen-Dazs',
#  'and',
#  'Ben',
#  'Jerry’s',
#  'However',
#  'there',
#  'are',
#  'also',
#  'numerous',
#  'other',
#  'brands',
#  'that',
#  'sell',
#  'dairy',
#  'free',
#  'ice',
#  'creams',
#  'in',
#  'stores',
#  'that',
#  'aren’t',
#  'quite',
#  'as',
#  'well-known',
#  'such',
#  'as',
#  'Outshine',
#  'Coconut',
#  'Bliss',
#  'Tofutti',
#  'and',
#  'SO',
#  'Delicious',
#  'You',
#  'can',
#  'experiment',
#  'with',
#  'all',
#  'of',
#  'these',
#  'different',
#  'brands',
#  'and',
#  'flavors',
#  'to',
#  'find',
#  'which',
#  'one',
#  'hits',
#  'the',
#  'spot',
#  'when',
#  'you',
#  'are',
#  'sitting',
#  'at',
#  'home',
#  "'",
#  "'In",
#  'the',
#  'past',
#  'eight',
#  'months',
#  'since',
#  'I',
#  'have',
#  'gone',
#  'dairy',
#  'free',
#  'I',
#  'have',
#  'discovered',
#  'numerous',
#  'alternatives',
#  'There',
#  'are',
#  'now',
#  'vegan',
#  'ice',
#  'creams',
#  'cashew',
#  'ice',
#  'creams',
#  'coconut',
#  'ice',
#  'creams',
#  'and',
#  'even',
#  'a',
#  'to-die-for',
#  'non-dairy',
#  'chocolate',
#  'salted',
#  'fudge',
#  'truffle',
#  'ice',
#  'cream',
#  'from',
#  'Haagen-Dazs',
#  'The',
#  'truth',
#  'is',
#  'that',
#  'it',
#  'has',
#  'now',
#  'become',
#  'much',
#  'easier',
#  'for',
#  'people',
#  'who',
#  'are',
#  'allergic',
#  'to',
#  'dairy',
#  'or',
#  'who',
#  'simply',
#  'choose',
#  'to',
#  'refrain',
#  'from',
#  'it',
#  'like',
#  'me',
#  'to',
#  'find',
#  'delicious',
#  'alternatives',
#  'to',
#  'their',
#  'favored',
#  'dessert',
#  'You',
#  'no',
#  'longer',
#  'need',
#  'to',
#  'give',
#  'up',
#  'a',
#  'little',
#  'bit',
#  'of',
#  'heaven',
#  'in',
#  'order',
#  'to',
#  'eat',
#  'safely',
#  'and',
#  'maintain',
#  'your',
#  'diet',
#  'choices',
#  'The',
#  'wonderful',
#  'world',
#  'of',
#  'dairy-free',
#  'ice',
#  'cream',
#  'has',
#  'only',
#  'begun',
#  "'",
#  "''",
#  "'Haagen-Dazs",
#  'Non',
#  'Dairy',
#  'Flavors',
#  'list',
#  'icon=”icon:',
#  'check-square-o”',
#  'icon_color=”',
#  'd81c5c”',
#  "'",
#  "''",
#  "'Chocolate",
#  'salted',
#  'fudge',
#  "truffle'",
#  "'Coconut",
#  "Caramel'",
#  "'Coconut",
#  'Cookies',
#  'and',
#  'Creme',
#  '–',
#  'Trio',
#  'Crispy',
#  "Layers'",
#  "'Crunchy",
#  'Peanut',
#  'Butter',
#  '–',
#  'Trio',
#  'Crispy',
#  "Layers'",
#  "'Mocha",
#  'Chocolate',
#  "Cookie'",
#  "'Peanut",
#  'Butter',
#  'Chocolate',
#  "Fudge'",
#  "'Mango",
#  "Sorbet'",
#  "'Peach",
#  "Sorbet'",
#  "'Lemon",
#  "Sorbet'",
#  "'Raspberry",
#  "Sorbet'",
#  "'Cinnamon",
#  "Buns'",
#  "'Peanut",
#  'Butter',
#  'Half',
#  "Baked'",
#  "'Caramel",
#  'Almond',
#  "Brittle'",
#  "'Cherry",
#  "Garcia'",
#  "'Chocolate",
#  'Fudge',
#  "Brownie'",
#  "'Chunky",
#  "Monkey'",
#  "'Coconut",
#  'Seven',
#  'Layer',
#  "Bar'",
#  "'Coffee",
#  'Caramel',
#  "Fudge'",
#  "'P",
#  'B',
#  "Cookies'",
#  "'",
#  'list',
#  'icon=”icon:',
#  'check-square-o”',
#  'icon_color=”',
#  'd81c5c”',
#  "'",
#  "'Berry",
#  "Blend'",
#  "'Strawberry",
#  "Banana'",
#  "'Sunrise",
#  "Blend'",
#  "'Tropical",
#  "Blend'",
#  "'I",
#  'grew',
#  'up',
#  'avoiding',
#  'a',
#  'large',
#  'quantity',
#  'of',
#  'dairy',
#  'for',
#  'it',
#  'had',
#  'always',
#  'aggravated',
#  'my',
#  'stomach',
#  'but',
#  'it',
#  'wasn’t',
#  'until',
#  'I',
#  'had',
#  'a',
#  'hard',
#  'time',
#  'breathing',
#  'during',
#  'exercise',
#  'that',
#  'I',
#  'gave',
#  'up',
#  'all',
#  'dairy',
#  'There',
#  'have',
#  'been',
#  'studies',
#  'that',
#  'show',
#  'dairy',
#  'can',
#  'cause',
#  'inflammation',
#  'so',
#  'I',
#  'believed',
#  'by',
#  'eliminating',
#  'dairy',
#  'from',
#  'my',
#  'diet',
#  'it',
#  'might',
#  'reduce',
#  'inflammation',
#  'in',
#  'my',
#  'lungs',
#  'Not',
#  'too',
#  'long',
#  'afterward',
#  'I',
#  'also',
#  'gave',
#  'up',
#  'gluten',
#  'for',
#  'the',
#  'same',
#  'reason',
#  'Although',
#  'I',
#  'came',
#  'to',
#  'learn',
#  'that',
#  'my',
#  'difficulty',
#  'breathing',
#  'came',
#  'from',
#  'something',
#  'called',
#  'vocal',
#  'cord',
#  'dysfunction',
#  'not',
#  'asthma',
#  'or',
#  'inflammation',
#  'in',
#  'my',
#  'lungs',
#  'I',
#  'continued',
#  'to',
#  'follow',
#  'a',
#  'gluten',
#  'and',
#  'dairy',
#  'free',
#  'diet',
#  'I',
#  'found',
#  'that',
#  'my',
#  'energy',
#  'was',
#  'more',
#  'consistent',
#  'I',
#  'no',
#  'longer',
#  'felt',
#  'like',
#  'I',
#  'went',
#  'through',
#  'random',
#  'spikes',
#  'and',
#  'falls',
#  'in',
#  'energy',
#  'It',
#  'helped',
#  'my',
#  'mood',
#  'and',
#  'I',
#  'felt',
#  'more',
#  'level',
#  'emotionally',
#  'I',
#  'had',
#  'fewer',
#  'stomach',
#  'aches',
#  'and',
#  'nausea',
#  'All',
#  'around',
#  'this',
#  'new',
#  'dairy',
#  'and',
#  'gluten',
#  'and',
#  'dairy',
#  'free',
#  'diet',
#  'worked',
#  'perfectly',
#  'for',
#  'me',
#  'as',
#  'an',
#  'athlete',
#  'I',
#  'have',
#  'now',
#  'been',
#  'following',
#  'this',
#  'diet',
#  'for',
#  'close',
#  'to',
#  'eight',
#  'months',
#  'This',
#  'new',
#  'diet',
#  'has',
#  'made',
#  'me',
#  'more',
#  'passionate',
#  'about',
#  'awareness',
#  'of',
#  'allergens',
#  'in',
#  'the',
#  'workplace',
#  'and',
#  'restaurants',
#  'the',
#  'field',
#  'my',
#  'aunt',
#  'works',
#  'in',
#  'as',
#  'I',
#  'have',
#  'seen',
#  'first',
#  'hand',
#  'how',
#  'hard',
#  'it',
#  'can',
#  'be',
#  'to',
#  'order',
#  'from',
#  'a',
#  'menu',
#  'and',
#  'I',
#  'am',
#  'not',
#  'allergic',
#  'I',
#  'want',
#  'people',
#  'with',
#  'all',
#  'allergies',
#  'and',
#  'preferences',
#  'to',
#  'feel',
#  'safe',
#  'and',
#  'comfortable',
#  'with',
#  'their',
#  'diet',
#  'whether',
#  'they',
#  'are',
#  'in',
#  'the',
#  'workplace',
#  'or',
#  'at',
#  'a',
#  'restaurant',
#  'or',
#  'looking',
#  'around',
#  'a',
#  'grocery',
#  'store',
#  'There',
#  'should',
#  'be',
#  'yummy',
#  'food',
#  'out',
#  'there',
#  'for',
#  'everybody',
#  "'",
#  '']

# %%
word_count = list(map(lambda x: (x, 1), words))
word_count
# Out:
# Out[35]: [('', 1),
#  ("'Ever", 1),
#  ('since', 1),
#  ('my', 1),
#  ('first', 1),
#  ('lick', 1),
#  ('of', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('it', 1),
#  ('has', 1),
#  ('been', 1),
#  ('an', 1),
#  ('endless', 1),
#  ('love', 1),
#  ('story', 1),
#  ('Trading', 1),
#  ('my', 1),
#  ('toy', 1),
#  ('out', 1),
#  ('for', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('at', 1),
#  ('Chick-fil-a', 1),
#  ('was', 1),
#  ('the', 1),
#  ('easiest', 1),
#  ('decision', 1),
#  ('I', 1),
#  ('ever', 1),
#  ('had', 1),
#  ('to', 1),
#  ('make', 1),
#  ('I', 1),
#  ('spent', 1),
#  ('every', 1),
#  ('spring', 1),
#  ('summer', 1),
#  ('fall', 1),
#  ('and', 1),
#  ('winter', 1),
#  ('craving', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('when', 1),
#  ('I', 1),
#  ('was', 1),
#  ('happy', 1),
#  ('sad', 1),
#  ('and', 1),
#  ('anywhere', 1),
#  ('in', 1),
#  ('between', 1),
#  ('After', 1),
#  ('giving', 1),
#  ('up', 1),
#  ('dairy', 1),
#  ('I', 1),
#  ('thought', 1),
#  ('my', 1),
#  ('long', 1),
#  ('and', 1),
#  ('faithful', 1),
#  ('love', 1),
#  ('story', 1),
#  ('with', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('had', 1),
#  ('come', 1),
#  ('crashing', 1),
#  ('to', 1),
#  ('an', 1),
#  ('end', 1),
#  ('but', 1),
#  ('I', 1),
#  ('soon', 1),
#  ('realized', 1),
#  ('how', 1),
#  ('many', 1),
#  ('other', 1),
#  ('options', 1),
#  ('I', 1),
#  ('have', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'The", 1),
#  ('first', 1),
#  ('destination', 1),
#  ('on', 1),
#  ('my', 1),
#  ('road', 1),
#  ('to', 1),
#  ('discovering', 1),
#  ('dairy-free', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('options', 1),
#  ('landed', 1),
#  ('with', 1),
#  ('the', 1),
#  ('classic', 1),
#  ('sorbet', 1),
#  ('This', 1),
#  ('dairy-', 1),
#  ('and', 1),
#  ('nut-free', 1),
#  ('option', 1),
#  ('is', 1),
#  ('also', 1),
#  ('free', 1),
#  ('of', 1),
#  ('most', 1),
#  ('common', 1),
#  ('allergens', 1),
#  ('while', 1),
#  ('maintaining', 1),
#  ('a', 1),
#  ('delicious', 1),
#  ('taste', 1),
#  ('Sorbet', 1),
#  ('has', 1),
#  ('sat', 1),
#  ('back', 1),
#  ('seat', 1),
#  ('to', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('for', 1),
#  ('years', 1),
#  ('but', 1),
#  ('at', 1),
#  ('almost', 1),
#  ('nearly', 1),
#  ('any', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('store', 1),
#  ('you', 1),
#  ('can', 1),
#  ('find', 1),
#  ('sorbet', 1),
#  ('It’s', 1),
#  ('very', 1),
#  ('sweet', 1),
#  ('so', 1),
#  ('it', 1),
#  ('easily', 1),
#  ('curbs', 1),
#  ('any', 1),
#  ('sweet', 1),
#  ('tooth', 1),
#  ('While', 1),
#  ('it', 1),
#  ('might', 1),
#  ('not', 1),
#  ('be', 1),
#  ('quite', 1),
#  ('as', 1),
#  ('creamy', 1),
#  ('as', 1),
#  ('regular', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('it’s', 1),
#  ('a', 1),
#  ('great', 1),
#  ('way', 1),
#  ('to', 1),
#  ('satiate', 1),
#  ('your', 1),
#  ('sugar', 1),
#  ('cravings', 1),
#  ('and', 1),
#  ('quench', 1),
#  ('your', 1),
#  ('thirst', 1),
#  ('at', 1),
#  ('the', 1),
#  ('same', 1),
#  ('time', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'One", 1),
#  ('of', 1),
#  ('the', 1),
#  ('things', 1),
#  ('that', 1),
#  ('made', 1),
#  ('me', 1),
#  ('fall', 1),
#  ('in', 1),
#  ('love', 1),
#  ('with', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('is', 1),
#  ('its', 1),
#  ('creamy', 1),
#  ('texture', 1),
#  ('that', 1),
#  ('melts', 1),
#  ('in', 1),
#  ('my', 1),
#  ('mouth', 1),
#  ('Although', 1),
#  ('sorbet', 1),
#  ('may', 1),
#  ('not', 1),
#  ('feature', 1),
#  ('this', 1),
#  ('there', 1),
#  ('are', 1),
#  ('numerous', 1),
#  ('vegan', 1),
#  ('soy', 1),
#  ('nut', 1),
#  ('and', 1),
#  ('coconut-based', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('that', 1),
#  ('provide', 1),
#  ('the', 1),
#  ('same', 1),
#  ('creamy', 1),
#  ('texture', 1),
#  ('and', 1),
#  ('offer', 1),
#  ('the', 1),
#  ('same', 1),
#  ('variety', 1),
#  ('of', 1),
#  ('flavors', 1),
#  ('—', 1),
#  ('chocolate', 1),
#  ('fruit', 1),
#  ('cookie', 1),
#  ('caramel', 1),
#  ('and', 1),
#  ('more', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'What’s", 1),
#  ('awesome', 1),
#  ('about', 1),
#  ('all', 1),
#  ('these', 1),
#  ('new', 1),
#  ('options', 1),
#  ('these', 1),
#  ('new', 1),
#  ('“alternative”', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('and', 1),
#  ('desserts', 1),
#  ('have', 1),
#  ('made', 1),
#  ('their', 1),
#  ('way', 1),
#  ('not', 1),
#  ('only', 1),
#  ('to', 1),
#  ('the', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('display', 1),
#  ('on', 1),
#  ('the', 1),
#  ('storefront', 1),
#  ('but', 1),
#  ('into', 1),
#  ('grocery', 1),
#  ('stores', 1),
#  ('too', 1),
#  ('Many', 1),
#  ('name', 1),
#  ('brand', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('store', 1),
#  ('chains', 1),
#  ('also', 1),
#  ('sell', 1),
#  ('pints', 1),
#  ('and', 1),
#  ('tubs', 1),
#  ('of', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('in', 1),
#  ('stores', 1),
#  ('so', 1),
#  ('you', 1),
#  ('will', 1),
#  ('be', 1),
#  ('able', 1),
#  ('to', 1),
#  ('find', 1),
#  ('dairy-free', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('from', 1),
#  ('Haagen-Dazs', 1),
#  ('and', 1),
#  ('Ben', 1),
#  ('Jerry’s', 1),
#  ('However', 1),
#  ('there', 1),
#  ('are', 1),
#  ('also', 1),
#  ('numerous', 1),
#  ('other', 1),
#  ('brands', 1),
#  ('that', 1),
#  ('sell', 1),
#  ('dairy', 1),
#  ('free', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('in', 1),
#  ('stores', 1),
#  ('that', 1),
#  ('aren’t', 1),
#  ('quite', 1),
#  ('as', 1),
#  ('well-known', 1),
#  ('such', 1),
#  ('as', 1),
#  ('Outshine', 1),
#  ('Coconut', 1),
#  ('Bliss', 1),
#  ('Tofutti', 1),
#  ('and', 1),
#  ('SO', 1),
#  ('Delicious', 1),
#  ('You', 1),
#  ('can', 1),
#  ('experiment', 1),
#  ('with', 1),
#  ('all', 1),
#  ('of', 1),
#  ('these', 1),
#  ('different', 1),
#  ('brands', 1),
#  ('and', 1),
#  ('flavors', 1),
#  ('to', 1),
#  ('find', 1),
#  ('which', 1),
#  ('one', 1),
#  ('hits', 1),
#  ('the', 1),
#  ('spot', 1),
#  ('when', 1),
#  ('you', 1),
#  ('are', 1),
#  ('sitting', 1),
#  ('at', 1),
#  ('home', 1),
#  ("'", 1),
#  ("'In", 1),
#  ('the', 1),
#  ('past', 1),
#  ('eight', 1),
#  ('months', 1),
#  ('since', 1),
#  ('I', 1),
#  ('have', 1),
#  ('gone', 1),
#  ('dairy', 1),
#  ('free', 1),
#  ('I', 1),
#  ('have', 1),
#  ('discovered', 1),
#  ('numerous', 1),
#  ('alternatives', 1),
#  ('There', 1),
#  ('are', 1),
#  ('now', 1),
#  ('vegan', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('cashew', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('coconut', 1),
#  ('ice', 1),
#  ('creams', 1),
#  ('and', 1),
#  ('even', 1),
#  ('a', 1),
#  ('to-die-for', 1),
#  ('non-dairy', 1),
#  ('chocolate', 1),
#  ('salted', 1),
#  ('fudge', 1),
#  ('truffle', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('from', 1),
#  ('Haagen-Dazs', 1),
#  ('The', 1),
#  ('truth', 1),
#  ('is', 1),
#  ('that', 1),
#  ('it', 1),
#  ('has', 1),
#  ('now', 1),
#  ('become', 1),
#  ('much', 1),
#  ('easier', 1),
#  ('for', 1),
#  ('people', 1),
#  ('who', 1),
#  ('are', 1),
#  ('allergic', 1),
#  ('to', 1),
#  ('dairy', 1),
#  ('or', 1),
#  ('who', 1),
#  ('simply', 1),
#  ('choose', 1),
#  ('to', 1),
#  ('refrain', 1),
#  ('from', 1),
#  ('it', 1),
#  ('like', 1),
#  ('me', 1),
#  ('to', 1),
#  ('find', 1),
#  ('delicious', 1),
#  ('alternatives', 1),
#  ('to', 1),
#  ('their', 1),
#  ('favored', 1),
#  ('dessert', 1),
#  ('You', 1),
#  ('no', 1),
#  ('longer', 1),
#  ('need', 1),
#  ('to', 1),
#  ('give', 1),
#  ('up', 1),
#  ('a', 1),
#  ('little', 1),
#  ('bit', 1),
#  ('of', 1),
#  ('heaven', 1),
#  ('in', 1),
#  ('order', 1),
#  ('to', 1),
#  ('eat', 1),
#  ('safely', 1),
#  ('and', 1),
#  ('maintain', 1),
#  ('your', 1),
#  ('diet', 1),
#  ('choices', 1),
#  ('The', 1),
#  ('wonderful', 1),
#  ('world', 1),
#  ('of', 1),
#  ('dairy-free', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('has', 1),
#  ('only', 1),
#  ('begun', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Haagen-Dazs", 1),
#  ('Non', 1),
#  ('Dairy', 1),
#  ('Flavors', 1),
#  ('list', 1),
#  ('icon=”icon:', 1),
#  ('check-square-o”', 1),
#  ('icon_color=”', 1),
#  ('d81c5c”', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Chocolate", 1),
#  ('salted', 1),
#  ('fudge', 1),
#  ("truffle'", 1),
#  ("'Coconut", 1),
#  ("Caramel'", 1),
#  ("'Coconut", 1),
#  ('Cookies', 1),
#  ('and', 1),
#  ('Creme', 1),
#  ('–', 1),
#  ('Trio', 1),
#  ('Crispy', 1),
#  ("Layers'", 1),
#  ("'Crunchy", 1),
#  ('Peanut', 1),
#  ('Butter', 1),
#  ('–', 1),
#  ('Trio', 1),
#  ('Crispy', 1),
#  ("Layers'", 1),
#  ("'Mocha", 1),
#  ('Chocolate', 1),
#  ("Cookie'", 1),
#  ("'Peanut", 1),
#  ('Butter', 1),
#  ('Chocolate', 1),
#  ("Fudge'", 1),
#  ("'Mango", 1),
#  ("Sorbet'", 1),
#  ("'Peach", 1),
#  ("Sorbet'", 1),
#  ("'Lemon", 1),
#  ("Sorbet'", 1),
#  ("'Raspberry", 1),
#  ("Sorbet'", 1),
#  ("'Cinnamon", 1),
#  ("Buns'", 1),
#  ("'Peanut", 1),
#  ('Butter', 1),
#  ('Half', 1),
#  ("Baked'", 1),
#  ("'Caramel", 1),
#  ('Almond', 1),
#  ("Brittle'", 1),
#  ("'Cherry", 1),
#  ("Garcia'", 1),
#  ("'Chocolate", 1),
#  ('Fudge', 1),
#  ("Brownie'", 1),
#  ("'Chunky", 1),
#  ("Monkey'", 1),
#  ("'Coconut", 1),
#  ('Seven', 1),
#  ('Layer', 1),
#  ("Bar'", 1),
#  ("'Coffee", 1),
#  ('Caramel', 1),
#  ("Fudge'", 1),
#  ("'P", 1),
#  ('B', 1),
#  ("Cookies'", 1),
#  ("'", 1),
#  ('list', 1),
#  ('icon=”icon:', 1),
#  ('check-square-o”', 1),
#  ('icon_color=”', 1),
#  ('d81c5c”', 1),
#  ("'", 1),
#  ("'Berry", 1),
#  ("Blend'", 1),
#  ("'Strawberry", 1),
#  ("Banana'", 1),
#  ("'Sunrise", 1),
#  ("Blend'", 1),
#  ("'Tropical", 1),
#  ("Blend'", 1),
#  ("'I", 1),
#  ('grew', 1),
#  ('up', 1),
#  ('avoiding', 1),
#  ('a', 1),
#  ('large', 1),
#  ('quantity', 1),
#  ('of', 1),
#  ('dairy', 1),
#  ('for', 1),
#  ('it', 1),
#  ('had', 1),
#  ('always', 1),
#  ('aggravated', 1),
#  ('my', 1),
#  ('stomach', 1),
#  ('but', 1),
#  ('it', 1),
#  ('wasn’t', 1),
#  ('until', 1),
#  ('I', 1),
#  ('had', 1),
#  ('a', 1),
#  ('hard', 1),
#  ('time', 1),
#  ('breathing', 1),
#  ('during', 1),
#  ('exercise', 1),
#  ('that', 1),
#  ('I', 1),
#  ('gave', 1),
#  ('up', 1),
#  ('all', 1),
#  ('dairy', 1),
#  ('There', 1),
#  ('have', 1),
#  ('been', 1),
#  ('studies', 1),
#  ('that', 1),
#  ('show', 1),
#  ('dairy', 1),
#  ('can', 1),
#  ('cause', 1),
#  ('inflammation', 1),
#  ('so', 1),
#  ('I', 1),
#  ('believed', 1),
#  ('by', 1),
#  ('eliminating', 1),
#  ('dairy', 1),
#  ('from', 1),
#  ('my', 1),
#  ('diet', 1),
#  ('it', 1),
#  ('might', 1),
#  ('reduce', 1),
#  ('inflammation', 1),
#  ('in', 1),
#  ('my', 1),
#  ('lungs', 1),
#  ('Not', 1),
#  ('too', 1),
#  ('long', 1),
#  ('afterward', 1),
#  ('I', 1),
#  ('also', 1),
#  ('gave', 1),
#  ('up', 1),
#  ('gluten', 1),
#  ('for', 1),
#  ('the', 1),
#  ('same', 1),
#  ('reason', 1),
#  ('Although', 1),
#  ('I', 1),
#  ('came', 1),
#  ('to', 1),
#  ('learn', 1),
#  ('that', 1),
#  ('my', 1),
#  ('difficulty', 1),
#  ('breathing', 1),
#  ('came', 1),
#  ('from', 1),
#  ('something', 1),
#  ('called', 1),
#  ('vocal', 1),
#  ('cord', 1),
#  ('dysfunction', 1),
#  ('not', 1),
#  ('asthma', 1),
#  ('or', 1),
#  ('inflammation', 1),
#  ('in', 1),
#  ('my', 1),
#  ('lungs', 1),
#  ('I', 1),
#  ('continued', 1),
#  ('to', 1),
#  ('follow', 1),
#  ('a', 1),
#  ('gluten', 1),
#  ('and', 1),
#  ('dairy', 1),
#  ('free', 1),
#  ('diet', 1),
#  ('I', 1),
#  ('found', 1),
#  ('that', 1),
#  ('my', 1),
#  ('energy', 1),
#  ('was', 1),
#  ('more', 1),
#  ('consistent', 1),
#  ('I', 1),
#  ('no', 1),
#  ('longer', 1),
#  ('felt', 1),
#  ('like', 1),
#  ('I', 1),
#  ('went', 1),
#  ('through', 1),
#  ('random', 1),
#  ('spikes', 1),
#  ('and', 1),
#  ('falls', 1),
#  ('in', 1),
#  ('energy', 1),
#  ('It', 1),
#  ('helped', 1),
#  ('my', 1),
#  ('mood', 1),
#  ('and', 1),
#  ('I', 1),
#  ('felt', 1),
#  ('more', 1),
#  ('level', 1),
#  ('emotionally', 1),
#  ('I', 1),
#  ('had', 1),
#  ('fewer', 1),
#  ('stomach', 1),
#  ('aches', 1),
#  ('and', 1),
#  ('nausea', 1),
#  ('All', 1),
#  ('around', 1),
#  ('this', 1),
#  ('new', 1),
#  ('dairy', 1),
#  ('and', 1),
#  ('gluten', 1),
#  ('and', 1),
#  ('dairy', 1),
#  ('free', 1),
#  ('diet', 1),
#  ('worked', 1),
#  ('perfectly', 1),
#  ('for', 1),
#  ('me', 1),
#  ('as', 1),
#  ('an', 1),
#  ('athlete', 1),
#  ('I', 1),
#  ('have', 1),
#  ('now', 1),
#  ('been', 1),
#  ('following', 1),
#  ('this', 1),
#  ('diet', 1),
#  ('for', 1),
#  ('close', 1),
#  ('to', 1),
#  ('eight', 1),
#  ('months', 1),
#  ('This', 1),
#  ('new', 1),
#  ('diet', 1),
#  ('has', 1),
#  ('made', 1),
#  ('me', 1),
#  ('more', 1),
#  ('passionate', 1),
#  ('about', 1),
#  ('awareness', 1),
#  ('of', 1),
#  ('allergens', 1),
#  ('in', 1),
#  ('the', 1),
#  ('workplace', 1),
#  ('and', 1),
#  ('restaurants', 1),
#  ('the', 1),
#  ('field', 1),
#  ('my', 1),
#  ('aunt', 1),
#  ('works', 1),
#  ('in', 1),
#  ('as', 1),
#  ('I', 1),
#  ('have', 1),
#  ('seen', 1),
#  ('first', 1),
#  ('hand', 1),
#  ('how', 1),
#  ('hard', 1),
#  ('it', 1),
#  ('can', 1),
#  ('be', 1),
#  ('to', 1),
#  ('order', 1),
#  ('from', 1),
#  ('a', 1),
#  ('menu', 1),
#  ('and', 1),
#  ('I', 1),
#  ('am', 1),
#  ('not', 1),
#  ('allergic', 1),
#  ('I', 1),
#  ('want', 1),
#  ('people', 1),
#  ('with', 1),
#  ('all', 1),
#  ('allergies', 1),
#  ('and', 1),
#  ('preferences', 1),
#  ('to', 1),
#  ('feel', 1),
#  ('safe', 1),
#  ('and', 1),
#  ('comfortable', 1),
#  ('with', 1),
#  ('their', 1),
#  ('diet', 1),
#  ('whether', 1),
#  ('they', 1),
#  ('are', 1),
#  ('in', 1),
#  ('the', 1),
#  ('workplace', 1),
#  ('or', 1),
#  ('at', 1),
#  ('a', 1),
#  ('restaurant', 1),
#  ('or', 1),
#  ('looking', 1),
#  ('around', 1),
#  ('a', 1),
#  ('grocery', 1),
#  ('store', 1),
#  ('There', 1),
#  ('should', 1),
#  ('be', 1),
#  ('yummy', 1),
#  ('food', 1),
#  ('out', 1),
#  ('there', 1),
#  ('for', 1),
#  ('everybody', 1),
#  ("'", 1),
#  ('', 1)]

# %%
word_counts = {}
for word in words:
    word = word.lower()
    word_counts[word] = word_counts.get(word, 0) + 1

print(f'Total number of words:  {sum(word_counts.values())}')
# Out:
# Total number of words:  823

# %%
print('\n\nList of Words: ')
print('\n\nWord \t\tFrequency ')
for key, values in word_counts.items():
    if key == '':   continue
    print(f' {key}: \t {values} ')
# Out:
# List of Words:
#
#
# Word 		Frequency
#  'ever: 	 1
#  since: 	 2
#  my: 	 13
#  first: 	 3
#  lick: 	 1
#  of: 	 10
#  ice: 	 21
#  cream: 	 14
#  it: 	 10
#  has: 	 5
#  been: 	 3
#  an: 	 3
#  endless: 	 1
#  love: 	 3
#  story: 	 2
#  trading: 	 1
#  toy: 	 1
#  out: 	 2
#  for: 	 8
#  at: 	 5
#  chick-fil-a: 	 1
#  was: 	 3
#  the: 	 16
#  easiest: 	 1
#  decision: 	 1
#  i: 	 23
#  ever: 	 1
#  had: 	 5
#  to: 	 19
#  make: 	 1
#  spent: 	 1
#  every: 	 1
#  spring: 	 1
#  summer: 	 1
#  fall: 	 2
#  and: 	 26
#  winter: 	 1
#  craving: 	 1
#  when: 	 2
#  happy: 	 1
#  sad: 	 1
#  anywhere: 	 1
#  in: 	 12
#  between: 	 1
#  after: 	 1
#  giving: 	 1
#  up: 	 5
#  dairy: 	 12
#  thought: 	 1
#  long: 	 2
#  faithful: 	 1
#  with: 	 6
#  come: 	 1
#  crashing: 	 1
#  end: 	 1
#  but: 	 4
#  soon: 	 1
#  realized: 	 1
#  how: 	 2
#  many: 	 2
#  other: 	 2
#  options: 	 3
#  have: 	 7
#  ': 	 9
#  '': 	 5
#  'the: 	 1
#  destination: 	 1
#  on: 	 2
#  road: 	 1
#  discovering: 	 1
#  dairy-free: 	 3
#  landed: 	 1
#  classic: 	 1
#  sorbet: 	 4
#  this: 	 5
#  dairy-: 	 1
#  nut-free: 	 1
#  option: 	 1
#  is: 	 3
#  also: 	 4
#  free: 	 5
#  most: 	 1
#  common: 	 1
#  allergens: 	 2
#  while: 	 2
#  maintaining: 	 1
#  a: 	 10
#  delicious: 	 3
#  taste: 	 1
#  sat: 	 1
#  back: 	 1
#  seat: 	 1
#  years: 	 1
#  almost: 	 1
#  nearly: 	 1
#  any: 	 2
#  store: 	 3
#  you: 	 5
#  can: 	 4
#  find: 	 4
#  it’s: 	 2
#  very: 	 1
#  sweet: 	 2
#  so: 	 4
#  easily: 	 1
#  curbs: 	 1
#  tooth: 	 1
#  might: 	 2
#  not: 	 6
#  be: 	 4
#  quite: 	 2
#  as: 	 6
#  creamy: 	 3
#  regular: 	 1
#  great: 	 1
#  way: 	 2
#  satiate: 	 1
#  your: 	 3
#  sugar: 	 1
#  cravings: 	 1
#  quench: 	 1
#  thirst: 	 1
#  same: 	 4
#  time: 	 2
#  'one: 	 1
#  things: 	 1
#  that: 	 10
#  made: 	 3
#  me: 	 4
#  its: 	 1
#  texture: 	 2
#  melts: 	 1
#  mouth: 	 1
#  although: 	 2
#  may: 	 1
#  feature: 	 1
#  there: 	 6
#  are: 	 6
#  numerous: 	 3
#  vegan: 	 2
#  soy: 	 1
#  nut: 	 1
#  coconut-based: 	 1
#  creams: 	 7
#  provide: 	 1
#  offer: 	 1
#  variety: 	 1
#  flavors: 	 3
#  —: 	 1
#  chocolate: 	 4
#  fruit: 	 1
#  cookie: 	 1
#  caramel: 	 2
#  more: 	 4
#  'what’s: 	 1
#  awesome: 	 1
#  about: 	 2
#  all: 	 5
#  these: 	 3
#  new: 	 4
#  “alternative”: 	 1
#  desserts: 	 1
#  their: 	 3
#  only: 	 2
#  display: 	 1
#  storefront: 	 1
#  into: 	 1
#  grocery: 	 2
#  stores: 	 3
#  too: 	 2
#  name: 	 1
#  brand: 	 1
#  chains: 	 1
#  sell: 	 2
#  pints: 	 1
#  tubs: 	 1
#  will: 	 1
#  able: 	 1
#  from: 	 6
#  haagen-dazs: 	 2
#  ben: 	 1
#  jerry’s: 	 1
#  however: 	 1
#  brands: 	 2
#  aren’t: 	 1
#  well-known: 	 1
#  such: 	 1
#  outshine: 	 1
#  coconut: 	 2
#  bliss: 	 1
#  tofutti: 	 1
#  experiment: 	 1
#  different: 	 1
#  which: 	 1
#  one: 	 1
#  hits: 	 1
#  spot: 	 1
#  sitting: 	 1
#  home: 	 1
#  'in: 	 1
#  past: 	 1
#  eight: 	 2
#  months: 	 2
#  gone: 	 1
#  discovered: 	 1
#  alternatives: 	 2
#  now: 	 3
#  cashew: 	 1
#  even: 	 1
#  to-die-for: 	 1
#  non-dairy: 	 1
#  salted: 	 2
#  fudge: 	 3
#  truffle: 	 1
#  truth: 	 1
#  become: 	 1
#  much: 	 1
#  easier: 	 1
#  people: 	 2
#  who: 	 2
#  allergic: 	 2
#  or: 	 4
#  simply: 	 1
#  choose: 	 1
#  refrain: 	 1
#  like: 	 2
#  favored: 	 1
#  dessert: 	 1
#  no: 	 2
#  longer: 	 2
#  need: 	 1
#  give: 	 1
#  little: 	 1
#  bit: 	 1
#  heaven: 	 1
#  order: 	 2
#  eat: 	 1
#  safely: 	 1
#  maintain: 	 1
#  diet: 	 7
#  choices: 	 1
#  wonderful: 	 1
#  world: 	 1
#  begun: 	 1
#  'haagen-dazs: 	 1
#  non: 	 1
#  list: 	 2
#  icon=”icon:: 	 2
#  check-square-o”: 	 2
#  icon_color=”: 	 2
#  d81c5c”: 	 2
#  'chocolate: 	 2
#  truffle': 	 1
#  'coconut: 	 3
#  caramel': 	 1
#  cookies: 	 1
#  creme: 	 1
#  –: 	 2
#  trio: 	 2
#  crispy: 	 2
#  layers': 	 2
#  'crunchy: 	 1
#  peanut: 	 1
#  butter: 	 3
#  'mocha: 	 1
#  cookie': 	 1
#  'peanut: 	 2
#  fudge': 	 2
#  'mango: 	 1
#  sorbet': 	 4
#  'peach: 	 1
#  'lemon: 	 1
#  'raspberry: 	 1
#  'cinnamon: 	 1
#  buns': 	 1
#  half: 	 1
#  baked': 	 1
#  'caramel: 	 1
#  almond: 	 1
#  brittle': 	 1
#  'cherry: 	 1
#  garcia': 	 1
#  brownie': 	 1
#  'chunky: 	 1
#  monkey': 	 1
#  seven: 	 1
#  layer: 	 1
#  bar': 	 1
#  'coffee: 	 1
#  'p: 	 1
#  b: 	 1
#  cookies': 	 1
#  'berry: 	 1
#  blend': 	 3
#  'strawberry: 	 1
#  banana': 	 1
#  'sunrise: 	 1
#  'tropical: 	 1
#  'i: 	 1
#  grew: 	 1
#  avoiding: 	 1
#  large: 	 1
#  quantity: 	 1
#  always: 	 1
#  aggravated: 	 1
#  stomach: 	 2
#  wasn’t: 	 1
#  until: 	 1
#  hard: 	 2
#  breathing: 	 2
#  during: 	 1
#  exercise: 	 1
#  gave: 	 2
#  studies: 	 1
#  show: 	 1
#  cause: 	 1
#  inflammation: 	 3
#  believed: 	 1
#  by: 	 1
#  eliminating: 	 1
#  reduce: 	 1
#  lungs: 	 2
#  afterward: 	 1
#  gluten: 	 3
#  reason: 	 1
#  came: 	 2
#  learn: 	 1
#  difficulty: 	 1
#  something: 	 1
#  called: 	 1
#  vocal: 	 1
#  cord: 	 1
#  dysfunction: 	 1
#  asthma: 	 1
#  continued: 	 1
#  follow: 	 1
#  found: 	 1
#  energy: 	 2
#  consistent: 	 1
#  felt: 	 2
#  went: 	 1
#  through: 	 1
#  random: 	 1
#  spikes: 	 1
#  falls: 	 1
#  helped: 	 1
#  mood: 	 1
#  level: 	 1
#  emotionally: 	 1
#  fewer: 	 1
#  aches: 	 1
#  nausea: 	 1
#  around: 	 2
#  worked: 	 1
#  perfectly: 	 1
#  athlete: 	 1
#  following: 	 1
#  close: 	 1
#  passionate: 	 1
#  awareness: 	 1
#  workplace: 	 2
#  restaurants: 	 1
#  field: 	 1
#  aunt: 	 1
#  works: 	 1
#  seen: 	 1
#  hand: 	 1
#  menu: 	 1
#  am: 	 1
#  want: 	 1
#  allergies: 	 1
#  preferences: 	 1
#  feel: 	 1
#  safe: 	 1
#  comfortable: 	 1
#  whether: 	 1
#  they: 	 1
#  restaurant: 	 1
#  looking: 	 1
#  should: 	 1
#  yummy: 	 1
#  food: 	 1
#  everybody: 	 1
